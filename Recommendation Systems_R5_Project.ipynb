# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Read and explore the dataset. (Rename column, plot histograms, find data characteristics)2. Take subset of dataset to make it less sparse/more dense. (For example, keep the users only who has given 50 or more number of ratings )

# %%
column = ['UserID', 'ProductID', 'Rating', 'TimeStamp']

# %%
df = pd.read_csv('ratings_Electronics.csv', names=column)

# %%
df.head()
# Out:
#            UserID   ProductID  Rating   TimeStamp
# 0   AKM1MP6P0OYPR  0132793040     5.0  1365811200
# 1  A2CX7LUOHB2NDG  0321732944     5.0  1341100800
# 2  A2NWSAGRHCP8N5  0439886341     1.0  1367193600
# 3  A2WNBOD3WNDNKT  0439886341     3.0  1374451200
# 4  A1GI0U4ZRJA8WN  0439886341     1.0  1334707200

# %%
df.groupby('UserID').count() > 50
# Out:
#                        ProductID  Rating  TimeStamp
# UserID
# A00000262KYZUE4J55XGL      False   False      False
# A000063614T1OE0BUSKUT      False   False      False
# A00009182QVLSWIGHLS1B      False   False      False
# A00009661LC9LQPGKJ24G      False   False      False
# A00010809P09NUU6ZP6H       False   False      False
# A00014061C2IZNE0YEILY      False   False      False
# A000145014WOTZJ5NSKOR      False   False      False
# A00015222LZ55IJSVL5IX      False   False      False
# A00015228CUPGPF957DS       False   False      False
# A0001528BGUBOEVR6T5U       False   False      False
# A00018041RRVMCICCAP79      False   False      False
# A000186437REL8X2RW8UW      False   False      False
# A000187635I595IAVSQLH      False   False      False
# A00019466UY2KR1IPXQN       False   False      False
# A0002012T7HVDB2EF4RH       False   False      False
# A0002032ZFQKDVHYKGWR       False   False      False
# A0002550196XWX0PEOZND      False   False      False
# ...

# %%
users = df["UserID"].value_counts() > 50

# %%
users
# Out:
# A5JLAU2ARJ0BO             True
# ADLVFFE4VBT8              True
# A3OXHLG6DIBRW8            True
# A6FIAB28IS79              True
# A680RUE1FDO8B             True
# A1ODOGXEYECQQ8            True
# A36K2N527TXXJN            True
# A2AY4YUOX2N1BQ            True
# AWPODHOB4GFWL             True
# A25C2M3QF9G7OQ            True
# ARBKYIVNYWK3C             True
# A22CW0ZHY3NJH8            True
# A38RMU1Y5TDP9             True
# A3EXWV8FNSSFL6            True
# A3LGT6UZL99IW1            True
# A2NOW4U7W3F7RI            True
# A23GFTVIETX7DS            True
# A3PD8JD9L4WEII            True
# A17BUUBOU0598B            True
# A3AYSYSLHU26U9            True
# A2XRMQA6PJ5ZJ8            True
# A12DQZKRKTNF5E            True
# A231WM2Z2JL0U3            True
# A1UQBFCERIP7VJ            True
# AGVWTYW0ULXHT             True
# A203OCQQ12MAVT            True
# AEJAGHLC675A7             True
# A2NYK9KWFMJV4Y            True
# A3A4ZAIBQWKOZS            True
# A1T1YSCDW0PD25            True
# ...
